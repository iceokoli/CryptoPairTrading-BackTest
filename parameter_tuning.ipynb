# %% [markdown]
# # Analyse the performance of the strategy with different parameters

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results/training/optimisation.csv')

# %% [markdown]
# Best Strategy has triggers set to 1std away from the mean and moving stats set with a period of 25

# %%
df.set_index(['Trigger','Period']).sort_index(ascending=False).plot(kind='barh', y='Return', use_index=True, figsize=(10,15))
