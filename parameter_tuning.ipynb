# %% [markdown]
# # Analyse the performance of the strategy with different parameters

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results/training/optimisation.csv')

# %% [markdown]
# Best Strategy has triggers set to 1std away from the mean and moving stats set with a period of 20 and sell at the most 0.1 std from the mean

# %%
df.set_index(
    ['Trigger','Period', 'Sell_mul']
).sort_values('Return',ascending=True).iloc[-10:].plot(kind='barh', y='Return', use_index=True, figsize=(10,15))
